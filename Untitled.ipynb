# %%
import pandas as pd
import os
dfs=pd.DataFrame()
#os.walk(file_path) 深度遍历file_path下的所有子文件夹及文件
for root_dir,sub_dir,files in os.walk(r"D:\Database数据库\Perovskite-sensor-1百万摘要webofscience\perovskite sensor(03-23)\新建文件夹\perovskite"):
    for file in files:
        if file.endswith(".xls"):
            #构造绝对路径
            file_name = os.path.join(root_dir, file)
            #读取sheet页
            #pd.read_excel(file_path,sheet_name=None).keys()获取excel表格所有的sheet页名称
            for sheet in  pd.read_excel(file_name,sheet_name=None).keys():
                df=pd.read_excel(file_name,sheet_name=sheet)
                excel_name=file.replace(".xlsx","")
                #新增两列用于记录数据所属excel及sheet页，这一步骤感觉很有用，因为后续数据清理的时候，遇到莫名其妙的数据不知道怎么办的话，还可以去源excel表格上看下。
                df["excel_name"]=excel_name
                df["sheet_name"]=sheet
                dfs=pd.concat([dfs,df])

# %%
dfs
# Out:
#     Publication Type                                            Authors  \
# 0                  J                                 Boukamp, Bernard A
# 1                  J    Xu, Zhengtao; Mitzi, David B; Medeiros, David R
# 2                  J  Mao, Yuanbing; Banerjee, Sarbajit; Wong, Stani...
# 3                  J  Badro, James; Fiquet, Guillaume; Guyot, Franco...
# 4                  J                            Zuniga, F J; Darriet, J
# ..               ...                                                ...
# 617                J  Xu, He; Zhu, Jianhao; Wu, Xiaohong; Cheng, Yux...
# 618                J  Zhang, Hao; Luo, Yu-Hui; Chen, Feng-Yu; Geng, ...
# 619                J  Gannouni, Afef; Tahri, Wiem; Roisnel, Thierry;...
# 620                J  Sanaei, Zahra; Shamsipur, Ali; Ramezanzadeh, B...
# 621                J  Wei, Dali; Li, Mingwei; Wang, Ying; Zhu, Nuanf...
#
#      Book Authors Group Authors  Book Group Authors  \
# 0             NaN           NaN                 NaN
# 1             NaN           NaN                 NaN
# 2             NaN           NaN                 NaN
# 3             NaN           NaN                 NaN
# 4             NaN           NaN                 NaN
# ..            ...           ...                 ...
# 617           NaN           NaN                 NaN
# 618           NaN           NaN                 NaN
# 619           NaN           NaN                 NaN
# 620           NaN           NaN                 NaN
# 621           NaN           NaN                 NaN
#
#                                         Researcher Ids  \
# 0                         Boukamp, Bernard/E-9924-2010
# 1    xu, zhengtao/J-3163-2013; Mitzi, David B/B-626...
# 2                            Mao, Yuanbing/D-5580-2009
# 3    Struzhkin, Viktor V/J-9847-2013; Fiquet, Guill...
# 4                      Zuniga, Fco. Javier/H-9154-2015
# ..                                                 ...
# 617                                                NaN
# 618                                                NaN
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                                                 ORCIDs Book Editors  \
# 0                 Boukamp, Bernard/0000-0001-7348-5385          NaN
# 1    Mitzi, David B/0000-0001-5189-4612; XU, Zhengt...          NaN
# 2               Banerjee, Sarbajit/0000-0002-2028-4675          NaN
# 3    Struzhkin, Viktor V/0000-0002-3468-0548; Vanko...          NaN
# 4              Zuniga, Fco. Javier/0000-0001-8616-0766          NaN
# ..                                                 ...          ...
# 617                                                NaN          NaN
# 618                                                NaN          NaN
# 619                                                NaN          NaN
# 620                                                NaN          NaN
# 621                                                NaN          NaN
#
#      Author - Arabic                                      Article Title  ...  \
# 0                NaN          Fuel cells: The amazing perovskite anode.  ...
# 1                NaN  [(CH3)3NCH2CH2NH3]SnI4: a layered perovskite w...  ...
# 2                NaN  Large-scale synthesis of single-crystalline pe...  ...
# 3                NaN  Iron partitioning in Earth's mantle: toward a ...  ...
# 4                NaN  NaCa4Nb5O17: a layered perovskite AnBnO3n+2 co...  ...
# ..               ...                                                ...  ...
# 617              NaN  Recognition and quantitative analysis for six ...  ...
# 618              NaN  Enhancing the spatial separation of photogener...  ...
# 619              NaN  X-ray diffraction, IR spectrum, optical proper...  ...
# 620              NaN  Trisodium phosphate-loaded hierarchically orde...  ...
# 621              NaN  Encapsulating gold nanoclusters into metal-org...  ...
#
#      180 Day Usage Count  Since 2013 Usage Count       ISSN      eISSN  ISBN  \
# 0                    NaN                     NaN  1476-1122        NaN   NaN
# 1                    NaN                     NaN  0020-1669        NaN   NaN
# 2                    NaN                     NaN  0002-7863        NaN   NaN
# 3                    NaN                     NaN        NaN  1095-9203   NaN
# 4                    NaN                     NaN  0108-2701        NaN   NaN
# ..                   ...                     ...        ...        ...   ...
# 617                  NaN                     NaN  1386-1425  1873-3557   NaN
# 618                  NaN                     NaN  0304-3894  1873-3336   NaN
# 619                  NaN                     NaN  0022-2860  1872-8014   NaN
# 620                  NaN                     NaN  1385-8947  1873-3212   NaN
# 621                  NaN                     NaN  0304-3894  1873-3336   NaN
#
#           UT (Unique ID)   Pubmed Id Unnamed: 63          excel_name  \
# 0       MEDLINE:12728231  12728231.0         NaN      2003-1-191.xls
# 1       MEDLINE:12611504  12611504.0         NaN      2003-1-191.xls
# 2       MEDLINE:14677942  14677942.0         NaN      2003-1-191.xls
# 3       MEDLINE:12677070  12677070.0         NaN      2003-1-191.xls
# 4       MEDLINE:12574639  12574639.0         NaN      2003-1-191.xls
# ..                   ...         ...         ...                 ...
# 617  WOS:000875167200007  36049297.0         NaN  2023 3001-3622.xls
# 618  WOS:000863090300006  36067554.0         NaN  2023 3001-3622.xls
# 619  WOS:000863231000008         NaN         NaN  2023 3001-3622.xls
# 620  WOS:000858433700001         NaN         NaN  2023 3001-3622.xls
# 621  WOS:000855130100001  36084467.0         NaN  2023 3001-3622.xls
#
#     sheet_name
# 0    savedrecs
# 1    savedrecs
# 2    savedrecs
# 3    savedrecs
# 4    savedrecs
# ..         ...
# 617  savedrecs
# 618  savedrecs
# 619  savedrecs
# 620  savedrecs
# 621  savedrecs
#
# [118712 rows x 66 columns]

# %%
dfs1=pd.DataFrame(dfs['Abstract'])

# %%
pd.set_option('display.width', 400)
dfs1
# Out:
#                                               Abstract
# 0                                                  NaN
# 1    The organic-inorganic hybrid [(CH(3))(3)NCH(2)...
# 2    Single-crystalline perovskite nanostructures w...
# 3    We measured the spin state of iron in ferroper...
# 4    Sodium tetracalcium pentaniobium heptadecaoxid...
# ..                                                 ...
# 617  A novel surface enhanced Raman scattering (SER...
# 618  Although iron-based metal-organic frameworks (...
# 619  The paper reports the preparation and structur...
# 620  Here, for the first time, a novel mesoporous m...
# 621  Gold nanoclusters (Au NCs) with luminescence p...
#
# [118712 rows x 1 columns]

# %%
dfs1.to_csv('perovskite.csv', index=False)
